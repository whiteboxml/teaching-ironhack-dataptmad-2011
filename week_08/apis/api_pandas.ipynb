# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # APIs

# %% [markdown]
# Application owners will often create APIs (or Application Programming Interface) so that their applications can talk to other applications. An API is a set of programmatic instructions for accessing software applications, and the data that comes from APIs typically contains some sort of structure (such as JSON)

# %% [markdown]
# The term REST (Representational State Transfer) is any interface between systems that uses HTTP for getting data or doing operations over these data in any possible format, such as XML or JSON

# %% [markdown]
# Fake REST API: https://jsonplaceholder.typicode.com/

# %% [markdown]
# ## 1. Simple Response

# %%
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')

json_data = response.json()

json_data[0:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd

df = pd.DataFrame(json_data)
df.head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# ## 2. Nested Response

# %%
response = requests.get('https://api.github.com/events')

json_data = response.json()

json_data[0:2]
# Out:
# [{'id': '14841735608',
#   'type': 'CreateEvent',
#   'actor': {'id': 77535509,
#    'login': 'Bogdan228-228',
#    'display_login': 'Bogdan228-228',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bogdan228-228',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77535509?'},
#   'repo': {'id': 330161250,
#    'name': 'Bogdan228-228/Stalker',
#    'url': 'https://api.github.com/repos/Bogdan228-228/Stalker'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-01-16T12:48:06Z'},
#  {'id': '14841735604',
#   'type': 'PushEvent',
#   'actor': {'id': 24249735,
#    'login': 'Preeternal',
#    'display_login': 'Preeternal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Preeternal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24249735?'},
#   'repo': {'id': 315304431,
#    'name': 'Preeternal/tsagre',
#    'url': 'https://api.github.com/repos/Preeternal/tsagre'},
#   'payload': {'push_id': 6361701778,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/apollo',
#    'head': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
#    'before': '5fc6a47a17e35d681b06d80c129eb0287fe80324',
#    'commits': [{'sha': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
#      'author': {'email': 'preeternal@ya.ru', 'name': 'Preeternal'},
#      'message': 'save',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Preeternal/tsagre/commits/966b5f67f7f246e251c362eb8bf2d2ad931ff255'}]},
#   'public': True,
#   'created_at': '2021-01-16T12:48:06Z'}]

# %%
test_json = {
'id': '14841735604',
  'type': 'PushEvent',
  'actor': {'id': 24249735,
   'login': 'Preeternal',
   'display_login': 'Preeternal',
   'gravatar_id': '',
   'url': 'https://api.github.com/users/Preeternal',
   'avatar_url': 'https://avatars.githubusercontent.com/u/24249735?'},
  'repo': {'id': 315304431,
   'name': 'Preeternal/tsagre',
   'url': 'https://api.github.com/repos/Preeternal/tsagre'},
  'payload': {'push_id': 6361701778,
   'size': 1,
   'distinct_size': 1,
   'ref': 'refs/heads/apollo',
   'head': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
   'before': '5fc6a47a17e35d681b06d80c129eb0287fe80324',
   'commits': [{'sha': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
     'author': {'email': 'preeternal@ya.ru', 'name': 'Preeternal'},
     'message': 'save',
     'distinct': True,
     'url': 'https://api.github.com/repos/Preeternal/tsagre/commits/966b5f67f7f246e251c362eb8bf2d2ad931ff255'}]},
  'public': True,
  'created_at': '2021-01-16T12:48:06Z'
  
}

test_json
# Out:
# {'id': '14841735604',
#  'type': 'PushEvent',
#  'actor': {'id': 24249735,
#   'login': 'Preeternal',
#   'display_login': 'Preeternal',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Preeternal',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/24249735?'},
#  'repo': {'id': 315304431,
#   'name': 'Preeternal/tsagre',
#   'url': 'https://api.github.com/repos/Preeternal/tsagre'},
#  'payload': {'push_id': 6361701778,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/apollo',
#   'head': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
#   'before': '5fc6a47a17e35d681b06d80c129eb0287fe80324',
#   'commits': [{'sha': '966b5f67f7f246e251c362eb8bf2d2ad931ff255',
#     'author': {'email': 'preeternal@ya.ru', 'name': 'Preeternal'},
#     'message': 'save',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/Preeternal/tsagre/commits/966b5f67f7f246e251c362eb8bf2d2ad931ff255'}]},
#  'public': True,
#  'created_at': '2021-01-16T12:48:06Z'}

# %%
test_json['payload']['commits'][0]['author']['email']
# Out:
# 'preeternal@ya.ru'

# %%
for json_item in json_data:
    try:
        print(json_item['payload']['commits'][0]['author']['email'])
    except:
        print('not a commit')
# Out:
# not a commit
# preeternal@ya.ru
# 77531466+azhanlang@users.noreply.github.com
# not a commit
# ubuntu@ip-172-31-6-222.us-east-2.compute.internal
# not a commit
# xuedong.pu@outlook.com
# not a commit
# not a commit
# not a commit
# not a commit
# not a commit
# giorgiocomitini@gmail.com
# neon.kang@gmail.com
# xndchn@gmail.com
# not a commit
# timron.work@gmail.com
# dasorange.hope@gmail.com
# newtowhid1232@gmail.com
# 75512606+Kxllnsh@users.noreply.github.com
# not a commit
# 63241686+xiaohuixian@users.noreply.github.com
# bmederbek5@gmail.com
# 63501250+bhargavi5299@users.noreply.github.com
# _alm_octane_auto@microfocus.com
# 74113347+commit-b0t@users.noreply.github.com
# not a commit
# not a commit
# not a commit
# not a commit

# %% [markdown]
# ### 2.1 Raw pandas

# %%
df = pd.DataFrame(json_data)
df.head()
# Out:
#             id         type  \
# 0  14841735608  CreateEvent
# 1  14841735604    PushEvent
# 2  14841735603    PushEvent
# 3  14841735602  CreateEvent
# 4  14841735598    PushEvent
#
#                                                actor  \
# 0  {'id': 77535509, 'login': 'Bogdan228-228', 'di...
# 1  {'id': 24249735, 'login': 'Preeternal', 'displ...
# 2  {'id': 77531466, 'login': 'azhanlang', 'displa...
# 3  {'id': 24797042, 'login': 'MiltonLand', 'displ...
# 4  {'id': 46749216, 'login': 'Shivangx01b', 'disp...
#
#                                                 repo  \
# 0  {'id': 330161250, 'name': 'Bogdan228-228/Stalk...
# 1  {'id': 315304431, 'name': 'Preeternal/tsagre',...
# 2  {'id': 330155588, 'name': 'azhanlang/shadowroc...
# 3  {'id': 330161249, 'name': 'MiltonLand/OdeToFoo...
# 4  {'id': 308013877, 'name': 'Shivangx01b/Fresh-D...
#
#                                              payload  public  \
# 0  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 1  {'push_id': 6361701778, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 6361701777, 'size': 1, 'distinct_s...    True
# 3  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 4  {'push_id': 6361701776, 'size': 1, 'distinct_s...    True
#
#              created_at  org
# 0  2021-01-16T12:48:06Z  NaN
# 1  2021-01-16T12:48:06Z  NaN
# 2  2021-01-16T12:48:06Z  NaN
# 3  2021-01-16T12:48:06Z  NaN
# 4  2021-01-16T12:48:06Z  NaN

# %% [markdown]
# Access the first element of column "actor" in 4 different ways:

# %%
column = 'actor'

# %%
df[column][0]
# Out:
# {'id': 77535509,
#  'login': 'Bogdan228-228',
#  'display_login': 'Bogdan228-228',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Bogdan228-228',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/77535509?'}

# %%
df.loc[0, column]
# Out:
# {'id': 77535509,
#  'login': 'Bogdan228-228',
#  'display_login': 'Bogdan228-228',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Bogdan228-228',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/77535509?'}

# %%
df.actor[0]
# Out:
# {'id': 77535509,
#  'login': 'Bogdan228-228',
#  'display_login': 'Bogdan228-228',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Bogdan228-228',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/77535509?'}

# %%
df.iloc[0, 2]
# Out:
# {'id': 77535509,
#  'login': 'Bogdan228-228',
#  'display_login': 'Bogdan228-228',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Bogdan228-228',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/77535509?'}

# %% [markdown]
# ### 2.2 json_normalize

# %%
pd.set_option('display.max_columns', None)

df_flattened = pd.json_normalize(json_data)

df_flattened.head()
# Out:
#             id         type  public            created_at  actor.id  \
# 0  14841735608  CreateEvent    True  2021-01-16T12:48:06Z  77535509
# 1  14841735604    PushEvent    True  2021-01-16T12:48:06Z  24249735
# 2  14841735603    PushEvent    True  2021-01-16T12:48:06Z  77531466
# 3  14841735602  CreateEvent    True  2021-01-16T12:48:06Z  24797042
# 4  14841735598    PushEvent    True  2021-01-16T12:48:06Z  46749216
#
#      actor.login actor.display_login actor.gravatar_id  \
# 0  Bogdan228-228       Bogdan228-228
# 1     Preeternal          Preeternal
# 2      azhanlang           azhanlang
# 3     MiltonLand          MiltonLand
# 4    Shivangx01b         Shivangx01b
#
#                                     actor.url  \
# 0  https://api.github.com/users/Bogdan228-228
# 1     https://api.github.com/users/Preeternal
# 2      https://api.github.com/users/azhanlang
# 3     https://api.github.com/users/MiltonLand
# 4    https://api.github.com/users/Shivangx01b
#
#                                     actor.avatar_url    repo.id  \
# 0  https://avatars.githubusercontent.com/u/77535509?  330161250
# 1  https://avatars.githubusercontent.com/u/24249735?  315304431
# 2  https://avatars.githubusercontent.com/u/77531466?  330155588
# 3  https://avatars.githubusercontent.com/u/24797042?  330161249
# 4  https://avatars.githubusercontent.com/u/46749216?  308013877
#
#                 repo.name                                           repo.url  \
# 0   Bogdan228-228/Stalker  https://api.github.com/repos/Bogdan228-228/Sta...
# 1       Preeternal/tsagre     https://api.github.com/repos/Preeternal/tsagre
# 2  azhanlang/shadowrocket  https://api.github.com/repos/azhanlang/shadowr...
# 3    MiltonLand/OdeToFood  https://api.github.com/repos/MiltonLand/OdeToFood
# 4   Shivangx01b/Fresh-Dns  https://api.github.com/repos/Shivangx01b/Fresh...
#
#          payload.ref payload.ref_type payload.master_branch  \
# 0               None       repository                master
# 1  refs/heads/apollo              NaN                   NaN
# 2  refs/heads/master              NaN                   NaN
# 3               None       repository                master
# 4    refs/heads/main              NaN                   NaN
#
#   payload.description payload.pusher_type  payload.push_id  payload.size  \
# 0                None                user              NaN           NaN
# 1                 NaN                 NaN     6.361702e+09           1.0
# 2                 NaN                 NaN     6.361702e+09           1.0
# 3  .Net Core Tutorial                user              NaN           NaN
# 4                 NaN                 NaN     6.361702e+09           1.0
#
#    payload.distinct_size                              payload.head  \
# 0                    NaN                                       NaN
# 1                    1.0  966b5f67f7f246e251c362eb8bf2d2ad931ff255
# 2                    1.0  ed2245cac92fe9de4d747eca7b3a474cd814b615
# 3                    NaN                                       NaN
# 4                    1.0  2f40066cb26b4921f4ba36e513bd1f5693ce4afc
#
#                              payload.before  \
# 0                                       NaN
# 1  5fc6a47a17e35d681b06d80c129eb0287fe80324
# 2  a15872b044ae7a4c329c3195e885e30cb54d720f
# 3                                       NaN
# 4  286e7234d2ea856ece96758464f16468118a8ff6
#
#                                      payload.commits payload.action  org.id  \
# 0                                                NaN            NaN     NaN
# 1  [{'sha': '966b5f67f7f246e251c362eb8bf2d2ad931f...            NaN     NaN
# 2  [{'sha': 'ed2245cac92fe9de4d747eca7b3a474cd814...            NaN     NaN
# 3                                                NaN            NaN     NaN
# 4  [{'sha': '2f40066cb26b4921f4ba36e513bd1f5693ce...            NaN     NaN
#
#   org.login org.gravatar_id org.url org.avatar_url payload.issue.url  \
# 0       NaN             NaN     NaN            NaN               NaN
# 1       NaN             NaN     NaN            NaN               NaN
# 2       NaN             NaN     NaN            NaN               NaN
# 3       NaN             NaN     NaN            NaN               NaN
# 4       NaN             NaN     NaN            NaN               NaN
#
#   payload.issue.repository_url payload.issue.labels_url  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
#
#   payload.issue.comments_url payload.issue.events_url payload.issue.html_url  \
# 0                        NaN                      NaN                    NaN
# 1                        NaN                      NaN                    NaN
# 2                        NaN                      NaN                    NaN
# 3                        NaN                      NaN                    NaN
# 4                        NaN                      NaN                    NaN
#
#    payload.issue.id payload.issue.node_id  payload.issue.number  \
# 0               NaN                   NaN                   NaN
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
#   payload.issue.title payload.issue.user.login  payload.issue.user.id  \
# 0                 NaN                      NaN                    NaN
# 1                 NaN                      NaN                    NaN
# 2                 NaN                      NaN                    NaN
# 3                 NaN                      NaN                    NaN
# 4                 NaN                      NaN                    NaN
#
#   payload.issue.user.node_id payload.issue.user.avatar_url  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#   payload.issue.user.gravatar_id payload.issue.user.url  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#   payload.issue.user.html_url payload.issue.user.followers_url  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
#
#   payload.issue.user.following_url payload.issue.user.gists_url  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#   payload.issue.user.starred_url payload.issue.user.subscriptions_url  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#   payload.issue.user.organizations_url payload.issue.user.repos_url  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
#
#   payload.issue.user.events_url payload.issue.user.received_events_url  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#   payload.issue.user.type payload.issue.user.site_admin payload.issue.labels  \
# 0                     NaN                           NaN                  NaN
# 1                     NaN                           NaN                  NaN
# 2                     NaN                           NaN                  NaN
# 3                     NaN                           NaN                  NaN
# 4                     NaN                           NaN                  NaN
#
#   payload.issue.state payload.issue.locked payload.issue.assignee.login  \
# 0                 NaN                  NaN                          NaN
# 1                 NaN                  NaN                          NaN
# 2                 NaN                  NaN                          NaN
# 3                 NaN                  NaN                          NaN
# 4                 NaN                  NaN                          NaN
#
#    payload.issue.assignee.id payload.issue.assignee.node_id  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#   payload.issue.assignee.avatar_url payload.issue.assignee.gravatar_id  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   payload.issue.assignee.url payload.issue.assignee.html_url  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#   payload.issue.assignee.followers_url payload.issue.assignee.following_url  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   payload.issue.assignee.gists_url payload.issue.assignee.starred_url  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#   payload.issue.assignee.subscriptions_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.issue.assignee.organizations_url payload.issue.assignee.repos_url  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   payload.issue.assignee.events_url  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#   payload.issue.assignee.received_events_url payload.issue.assignee.type  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
#
#   payload.issue.assignee.site_admin payload.issue.assignees  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
#
#    payload.issue.milestone  payload.issue.comments payload.issue.created_at  \
# 0                      NaN                     NaN                      NaN
# 1                      NaN                     NaN                      NaN
# 2                      NaN                     NaN                      NaN
# 3                      NaN                     NaN                      NaN
# 4                      NaN                     NaN                      NaN
#
#   payload.issue.updated_at  payload.issue.closed_at  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   payload.issue.author_association  payload.issue.active_lock_reason  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   payload.issue.body  payload.issue.performed_via_github_app  \
# 0                NaN                                     NaN
# 1                NaN                                     NaN
# 2                NaN                                     NaN
# 3                NaN                                     NaN
# 4                NaN                                     NaN
#
#    payload.issue.assignee payload.issue.pull_request.url  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
#
#   payload.issue.pull_request.html_url payload.issue.pull_request.diff_url  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   payload.issue.pull_request.patch_url payload.comment.url  \
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
#
#   payload.comment.html_url payload.comment.issue_url  payload.comment.id  \
# 0                      NaN                       NaN                 NaN
# 1                      NaN                       NaN                 NaN
# 2                      NaN                       NaN                 NaN
# 3                      NaN                       NaN                 NaN
# 4                      NaN                       NaN                 NaN
#
#   payload.comment.node_id payload.comment.user.login  payload.comment.user.id  \
# 0                     NaN                        NaN                      NaN
# 1                     NaN                        NaN                      NaN
# 2                     NaN                        NaN                      NaN
# 3                     NaN                        NaN                      NaN
# 4                     NaN                        NaN                      NaN
#
#   payload.comment.user.node_id payload.comment.user.avatar_url  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#   payload.comment.user.gravatar_id payload.comment.user.url  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
#
#   payload.comment.user.html_url payload.comment.user.followers_url  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#   payload.comment.user.following_url payload.comment.user.gists_url  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   payload.comment.user.starred_url payload.comment.user.subscriptions_url  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
#
#   payload.comment.user.organizations_url payload.comment.user.repos_url  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                    NaN                            NaN
# 3                                    NaN                            NaN
# 4                                    NaN                            NaN
#
#   payload.comment.user.events_url payload.comment.user.received_events_url  \
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
#
#   payload.comment.user.type payload.comment.user.site_admin  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   payload.comment.created_at payload.comment.updated_at  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   payload.comment.author_association payload.comment.body  \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
#
#    payload.comment.performed_via_github_app  payload.number  \
# 0                                       NaN             NaN
# 1                                       NaN             NaN
# 2                                       NaN             NaN
# 3                                       NaN             NaN
# 4                                       NaN             NaN
#
#   payload.pull_request.url  payload.pull_request.id  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#   payload.pull_request.node_id payload.pull_request.html_url  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   payload.pull_request.diff_url payload.pull_request.patch_url  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   payload.pull_request.issue_url  payload.pull_request.number  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   payload.pull_request.state payload.pull_request.locked  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   payload.pull_request.title payload.pull_request.user.login  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    payload.pull_request.user.id payload.pull_request.user.node_id  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   payload.pull_request.user.avatar_url payload.pull_request.user.gravatar_id  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
#
#   payload.pull_request.user.url payload.pull_request.user.html_url  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#   payload.pull_request.user.followers_url  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   payload.pull_request.user.following_url payload.pull_request.user.gists_url  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   payload.pull_request.user.starred_url  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   payload.pull_request.user.subscriptions_url  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   payload.pull_request.user.organizations_url  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   payload.pull_request.user.repos_url payload.pull_request.user.events_url  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   payload.pull_request.user.received_events_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   payload.pull_request.user.type payload.pull_request.user.site_admin  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#   payload.pull_request.body payload.pull_request.created_at  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   payload.pull_request.updated_at payload.pull_request.closed_at  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    payload.pull_request.merged_at payload.pull_request.merge_commit_sha  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
#
#    payload.pull_request.assignee payload.pull_request.assignees  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   payload.pull_request.requested_reviewers  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.requested_teams payload.pull_request.labels  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    payload.pull_request.milestone payload.pull_request.draft  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#   payload.pull_request.commits_url payload.pull_request.review_comments_url  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
#
#   payload.pull_request.review_comment_url payload.pull_request.comments_url  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
#
#   payload.pull_request.statuses_url payload.pull_request.head.label  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   payload.pull_request.head.ref payload.pull_request.head.sha  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   payload.pull_request.head.user.login  payload.pull_request.head.user.id  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#   payload.pull_request.head.user.node_id  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request.head.user.avatar_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.head.user.gravatar_id  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.head.user.url payload.pull_request.head.user.html_url  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
#
#   payload.pull_request.head.user.followers_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.head.user.following_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.head.user.gists_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.head.user.starred_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.head.user.subscriptions_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.head.user.organizations_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.head.user.repos_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.head.user.events_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.head.user.received_events_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.head.user.type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   payload.pull_request.head.user.site_admin  payload.pull_request.head.repo  \
# 0                                       NaN                             NaN
# 1                                       NaN                             NaN
# 2                                       NaN                             NaN
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
#
#   payload.pull_request.base.label payload.pull_request.base.ref  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   payload.pull_request.base.sha payload.pull_request.base.user.login  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
#
#    payload.pull_request.base.user.id payload.pull_request.base.user.node_id  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   payload.pull_request.base.user.avatar_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.user.gravatar_id  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.base.user.url payload.pull_request.base.user.html_url  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
#
#   payload.pull_request.base.user.followers_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.base.user.following_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.base.user.gists_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.user.starred_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.base.user.subscriptions_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.base.user.organizations_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.base.user.repos_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.user.events_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.user.received_events_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.base.user.type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   payload.pull_request.base.user.site_admin  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    payload.pull_request.base.repo.id payload.pull_request.base.repo.node_id  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   payload.pull_request.base.repo.name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   payload.pull_request.base.repo.full_name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.private  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request.base.repo.owner.login  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    payload.pull_request.base.repo.owner.id  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.owner.node_id  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.base.repo.owner.avatar_url  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   payload.pull_request.base.repo.owner.gravatar_id  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.base.repo.owner.url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.owner.html_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   payload.pull_request.base.repo.owner.followers_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.base.repo.owner.following_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.base.repo.owner.gists_url  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# ...
#
#   payload.pull_request.base.repo.merges_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.archive_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.base.repo.downloads_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.base.repo.issues_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.pulls_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.milestones_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   payload.pull_request.base.repo.notifications_url  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request.base.repo.labels_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.releases_url  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   payload.pull_request.base.repo.deployments_url  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   payload.pull_request.base.repo.created_at  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.updated_at  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.pushed_at  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.git_url  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request.base.repo.ssh_url  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request.base.repo.clone_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.svn_url  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request.base.repo.homepage  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    payload.pull_request.base.repo.size  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    payload.pull_request.base.repo.stargazers_count  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    payload.pull_request.base.repo.watchers_count  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   payload.pull_request.base.repo.language  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   payload.pull_request.base.repo.has_issues  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.base.repo.has_projects  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   payload.pull_request.base.repo.has_downloads  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   payload.pull_request.base.repo.has_wiki  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   payload.pull_request.base.repo.has_pages  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    payload.pull_request.base.repo.forks_count  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    payload.pull_request.base.repo.mirror_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   payload.pull_request.base.repo.archived  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   payload.pull_request.base.repo.disabled  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    payload.pull_request.base.repo.open_issues_count  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    payload.pull_request.base.repo.license  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    payload.pull_request.base.repo.forks  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    payload.pull_request.base.repo.open_issues  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    payload.pull_request.base.repo.watchers  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.base.repo.default_branch  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   payload.pull_request._links.self.href payload.pull_request._links.html.href  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   payload.pull_request._links.issue.href  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   payload.pull_request._links.comments.href  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request._links.review_comments.href  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   payload.pull_request._links.review_comment.href  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   payload.pull_request._links.commits.href  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request._links.statuses.href  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.author_association  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    payload.pull_request.active_lock_reason payload.pull_request.merged  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
#
#   payload.pull_request.mergeable payload.pull_request.rebaseable  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   payload.pull_request.mergeable_state  payload.pull_request.merged_by  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#    payload.pull_request.comments  payload.pull_request.review_comments  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#   payload.pull_request.maintainer_can_modify  payload.pull_request.commits  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
#
#    payload.pull_request.additions  payload.pull_request.deletions  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    payload.pull_request.changed_files
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN

# %%
df_flattened.columns
# Out:
# Index(['id', 'type', 'public', 'created_at', 'actor.id', 'actor.login',
#        'actor.display_login', 'actor.gravatar_id', 'actor.url',
#        'actor.avatar_url',
#        ...
#        'payload.pull_request.rebaseable',
#        'payload.pull_request.mergeable_state',
#        'payload.pull_request.merged_by', 'payload.pull_request.comments',
#        'payload.pull_request.review_comments',
#        'payload.pull_request.maintainer_can_modify',
#        'payload.pull_request.commits', 'payload.pull_request.additions',
#        'payload.pull_request.deletions', 'payload.pull_request.changed_files'],
#       dtype='object', length=325)

# %%
df_flattened_l1 = pd.json_normalize(json_data, max_level=1)

df_flattened_l1.head()
# Out:
#             id         type  public            created_at  actor.id  \
# 0  14841735608  CreateEvent    True  2021-01-16T12:48:06Z  77535509
# 1  14841735604    PushEvent    True  2021-01-16T12:48:06Z  24249735
# 2  14841735603    PushEvent    True  2021-01-16T12:48:06Z  77531466
# 3  14841735602  CreateEvent    True  2021-01-16T12:48:06Z  24797042
# 4  14841735598    PushEvent    True  2021-01-16T12:48:06Z  46749216
#
#      actor.login actor.display_login actor.gravatar_id  \
# 0  Bogdan228-228       Bogdan228-228
# 1     Preeternal          Preeternal
# 2      azhanlang           azhanlang
# 3     MiltonLand          MiltonLand
# 4    Shivangx01b         Shivangx01b
#
#                                     actor.url  \
# 0  https://api.github.com/users/Bogdan228-228
# 1     https://api.github.com/users/Preeternal
# 2      https://api.github.com/users/azhanlang
# 3     https://api.github.com/users/MiltonLand
# 4    https://api.github.com/users/Shivangx01b
#
#                                     actor.avatar_url    repo.id  \
# 0  https://avatars.githubusercontent.com/u/77535509?  330161250
# 1  https://avatars.githubusercontent.com/u/24249735?  315304431
# 2  https://avatars.githubusercontent.com/u/77531466?  330155588
# 3  https://avatars.githubusercontent.com/u/24797042?  330161249
# 4  https://avatars.githubusercontent.com/u/46749216?  308013877
#
#                 repo.name                                           repo.url  \
# 0   Bogdan228-228/Stalker  https://api.github.com/repos/Bogdan228-228/Sta...
# 1       Preeternal/tsagre     https://api.github.com/repos/Preeternal/tsagre
# 2  azhanlang/shadowrocket  https://api.github.com/repos/azhanlang/shadowr...
# 3    MiltonLand/OdeToFood  https://api.github.com/repos/MiltonLand/OdeToFood
# 4   Shivangx01b/Fresh-Dns  https://api.github.com/repos/Shivangx01b/Fresh...
#
#          payload.ref payload.ref_type payload.master_branch  \
# 0               None       repository                master
# 1  refs/heads/apollo              NaN                   NaN
# 2  refs/heads/master              NaN                   NaN
# 3               None       repository                master
# 4    refs/heads/main              NaN                   NaN
#
#   payload.description payload.pusher_type  payload.push_id  payload.size  \
# 0                None                user              NaN           NaN
# 1                 NaN                 NaN     6.361702e+09           1.0
# 2                 NaN                 NaN     6.361702e+09           1.0
# 3  .Net Core Tutorial                user              NaN           NaN
# 4                 NaN                 NaN     6.361702e+09           1.0
#
#    payload.distinct_size                              payload.head  \
# 0                    NaN                                       NaN
# 1                    1.0  966b5f67f7f246e251c362eb8bf2d2ad931ff255
# 2                    1.0  ed2245cac92fe9de4d747eca7b3a474cd814b615
# 3                    NaN                                       NaN
# 4                    1.0  2f40066cb26b4921f4ba36e513bd1f5693ce4afc
#
#                              payload.before  \
# 0                                       NaN
# 1  5fc6a47a17e35d681b06d80c129eb0287fe80324
# 2  a15872b044ae7a4c329c3195e885e30cb54d720f
# 3                                       NaN
# 4  286e7234d2ea856ece96758464f16468118a8ff6
#
#                                      payload.commits payload.action  org.id  \
# 0                                                NaN            NaN     NaN
# 1  [{'sha': '966b5f67f7f246e251c362eb8bf2d2ad931f...            NaN     NaN
# 2  [{'sha': 'ed2245cac92fe9de4d747eca7b3a474cd814...            NaN     NaN
# 3                                                NaN            NaN     NaN
# 4  [{'sha': '2f40066cb26b4921f4ba36e513bd1f5693ce...            NaN     NaN
#
#   org.login org.gravatar_id org.url org.avatar_url payload.issue  \
# 0       NaN             NaN     NaN            NaN           NaN
# 1       NaN             NaN     NaN            NaN           NaN
# 2       NaN             NaN     NaN            NaN           NaN
# 3       NaN             NaN     NaN            NaN           NaN
# 4       NaN             NaN     NaN            NaN           NaN
#
#   payload.comment  payload.number payload.pull_request
# 0             NaN             NaN                  NaN
# 1             NaN             NaN                  NaN
# 2             NaN             NaN                  NaN
# 3             NaN             NaN                  NaN
# 4             NaN             NaN                  NaN

# %%
len(df_flattened_l1.columns)
# Out:
# 34

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
