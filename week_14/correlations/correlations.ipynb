# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # Correlations

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# https://support.minitab.com/en-us/minitab-express/1/help-and-how-to/modeling-statistics/regression/supporting-topics/basics/a-comparison-of-the-pearson-and-spearman-correlation-methods/

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vehicles = pd.read_csv('../../week_05/pandas_import_export/data/vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## 2. Correlation Analysis

# %%
vehicles['City MPG'].corr(vehicles['Highway MPG'])
# Out:
# 0.9238555885288396

# %%
vehicles['City MPG'].corr(vehicles['City MPG'])
# Out:
# 1.0

# %%
vehicles.corr()
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# Fuel Barrels/Year                 1.000000 -0.877752    -0.909664
# City MPG                         -0.877752  1.000000     0.923856
# Highway MPG                      -0.909664  0.923856     1.000000
# Combined MPG                     -0.909743  0.985457     0.969392
# CO2 Emission Grams/Mile           0.986189 -0.894139    -0.926405
# Fuel Cost/Year                    0.916208 -0.858645    -0.851404
#
#                          Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# Year                         0.204751                -0.222300       -0.091913
# Engine Displacement         -0.746782                 0.803520        0.769678
# Cylinders                   -0.698648                 0.752393        0.778153
# Fuel Barrels/Year           -0.909743                 0.986189        0.916208
# City MPG                     0.985457                -0.894139       -0.858645
# Highway MPG                  0.969392                -0.926405       -0.851404
# Combined MPG                 1.000000                -0.926229       -0.875185
# CO2 Emission Grams/Mile     -0.926229                 1.000000        0.930865
# Fuel Cost/Year              -0.875185                 0.930865        1.000000

# %% [markdown]
# ## 3. Plots

# %% [markdown]
# ### 3.1 Pandas

# %%
plt.scatter(vehicles['City MPG'], vehicles['Highway MPG']);

# %%
vehicles.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b7e6e_row0_col0,#T_b7e6e_row1_col1,#T_b7e6e_row2_col2,#T_b7e6e_row3_col3,#T_b7e6e_row4_col4,#T_b7e6e_row5_col5,#T_b7e6e_row6_col6,#T_b7e6e_row7_col7,#T_b7e6e_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b7e6e_row0_col1{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_b7e6e_row0_col2{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_b7e6e_row0_col3{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_b7e6e_row0_col4{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_b7e6e_row0_col5{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_b7e6e_row0_col6{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_b7e6e_row0_col7{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_b7e6e_row0_col8{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_b7e6e_row1_col0{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_b7e6e_row1_col2,#T_b7e6e_row2_col1{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_b7e6e_row1_col3,#T_b7e6e_row7_col1{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_b7e6e_row1_col4{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b7e6e_row1_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_b7e6e_row1_col6{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_b7e6e_row1_col7{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_b7e6e_row1_col8{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_b7e6e_row2_col0{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_b7e6e_row2_col3{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_b7e6e_row2_col4{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_b7e6e_row2_col5{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_b7e6e_row2_col6{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_b7e6e_row2_col7{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_b7e6e_row2_col8,#T_b7e6e_row3_col1{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_b7e6e_row3_col0,#T_b7e6e_row4_col1,#T_b7e6e_row4_col2,#T_b7e6e_row5_col3,#T_b7e6e_row5_col7,#T_b7e6e_row6_col1,#T_b7e6e_row6_col2,#T_b7e6e_row6_col3,#T_b7e6e_row6_col7,#T_b7e6e_row6_col8,#T_b7e6e_row7_col0,#T_b7e6e_row7_col4,#T_b7e6e_row7_col5,#T_b7e6e_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b7e6e_row3_col2{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_b7e6e_row3_col4,#T_b7e6e_row3_col5,#T_b7e6e_row3_col6,#T_b7e6e_row4_col8{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_b7e6e_row3_col7,#T_b7e6e_row4_col6,#T_b7e6e_row6_col4,#T_b7e6e_row7_col3{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_b7e6e_row3_col8,#T_b7e6e_row8_col3{
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }#T_b7e6e_row4_col0{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_b7e6e_row4_col3,#T_b7e6e_row4_col7,#T_b7e6e_row5_col1,#T_b7e6e_row8_col4{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_b7e6e_row4_col5,#T_b7e6e_row5_col4{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_b7e6e_row5_col0{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_b7e6e_row5_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_b7e6e_row5_col6,#T_b7e6e_row6_col5{
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }#T_b7e6e_row5_col8{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_b7e6e_row6_col0{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_b7e6e_row7_col2{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_b7e6e_row7_col8,#T_b7e6e_row8_col7{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_b7e6e_row8_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_b7e6e_row8_col1,#T_b7e6e_row8_col2{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_b7e6e_row8_col5{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_b7e6e_row8_col6{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }</style><table id="T_b7e6e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Engine Displacement</th>        <th class="col_heading level0 col2" >Cylinders</th>        <th class="col_heading level0 col3" >Fuel Barrels/Year</th>        <th class="col_heading level0 col4" >City MPG</th>        <th class="col_heading level0 col5" >Highway MPG</th>        <th class="col_heading level0 col6" >Combined MPG</th>        <th class="col_heading level0 col7" >CO2 Emission Grams/Mile</th>        <th class="col_heading level0 col8" >Fuel Cost/Year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7e6e_level0_row0" class="row_heading level0 row0" >Year</th>
#                         <td id="T_b7e6e_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_b7e6e_row0_col1" class="data row0 col1" >0.04</td>
#                         <td id="T_b7e6e_row0_col2" class="data row0 col2" >0.08</td>
#                         <td id="T_b7e6e_row0_col3" class="data row0 col3" >-0.22</td>
#                         <td id="T_b7e6e_row0_col4" class="data row0 col4" >0.16</td>
#                         <td id="T_b7e6e_row0_col5" class="data row0 col5" >0.27</td>
#                         <td id="T_b7e6e_row0_col6" class="data row0 col6" >0.20</td>
#                         <td id="T_b7e6e_row0_col7" class="data row0 col7" >-0.22</td>
#                         <td id="T_b7e6e_row0_col8" class="data row0 col8" >-0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_b7e6e_level0_row1" class="row_heading level0 row1" >Engine Displacement</th>
#                         <td id="T_b7e6e_row1_col0" class="data row1 col0" >0.04</td>
#                         <td id="T_b7e6e_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_b7e6e_row1_col2" class="data row1 col2" >0.90</td>
#                         <td id="T_b7e6e_row1_col3" class="data row1 col3" >0.79</td>
#                         <td id="T_b7e6e_row1_col4" class="data row1 col4" >-0.74</td>
#                         <td id="T_b7e6e_row1_col5" class="data row1 col5" >-0.72</td>
#                         <td id="T_b7e6e_row1_col6" class="data row1 col6" >-0.75</td>
#                         <td id="T_b7e6e_row1_col7" class="data row1 col7" >0.80</td>
#                         <td id="T_b7e6e_row1_col8" class="data row1 col8" >0.77</td>
#             </tr>
#             <tr>
#                         <th id="T_b7e6e_level0_row2" class="row_heading level0 row2" >Cylinders</th>
#                         <td id="T_b7e6e_row2_col0" class="data row2 col0" >0.08</td>
#                         <td id="T_b7e6e_row2_col1" class="data row2 col1" >0.90</td>
#                         <td id="T_b7e6e_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_b7e6e_row2_col3" class="data row2 col3" >0.74</td>
#                         <td id="T_b7e6e_row2_col4" class="data row2 col4" >-0.70</td>

# %%
vehicles.corr(method='spearman').style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_a104c_row0_col0,#T_a104c_row1_col1,#T_a104c_row2_col2,#T_a104c_row3_col3,#T_a104c_row3_col7,#T_a104c_row4_col4,#T_a104c_row5_col5,#T_a104c_row6_col6,#T_a104c_row7_col3,#T_a104c_row7_col7,#T_a104c_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a104c_row0_col1,#T_a104c_row0_col2{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_a104c_row0_col3{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_a104c_row0_col4{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_a104c_row0_col5{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_a104c_row0_col6{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_a104c_row0_col7{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_a104c_row0_col8{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_a104c_row1_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_a104c_row1_col2,#T_a104c_row3_col8,#T_a104c_row7_col8,#T_a104c_row8_col3{
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }#T_a104c_row1_col3{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_a104c_row1_col4{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_a104c_row1_col5,#T_a104c_row2_col6{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_a104c_row1_col6{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_a104c_row1_col7{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_a104c_row1_col8,#T_a104c_row2_col3,#T_a104c_row2_col7,#T_a104c_row2_col8{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_a104c_row2_col0{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_a104c_row2_col1,#T_a104c_row4_col5,#T_a104c_row5_col4,#T_a104c_row8_col7{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_a104c_row2_col4{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_a104c_row2_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_a104c_row3_col0,#T_a104c_row3_col4,#T_a104c_row3_col5,#T_a104c_row3_col6,#T_a104c_row4_col1,#T_a104c_row4_col2,#T_a104c_row4_col8,#T_a104c_row6_col3,#T_a104c_row6_col7,#T_a104c_row6_col8,#T_a104c_row7_col0,#T_a104c_row7_col4,#T_a104c_row7_col5,#T_a104c_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_a104c_row3_col1,#T_a104c_row7_col1{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_a104c_row3_col2{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_a104c_row4_col0{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_a104c_row4_col3{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_a104c_row4_col6,#T_a104c_row6_col4{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_a104c_row4_col7{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_a104c_row5_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_a104c_row5_col1{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_a104c_row5_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_a104c_row5_col3,#T_a104c_row5_col7,#T_a104c_row6_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_a104c_row5_col6,#T_a104c_row6_col5{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_a104c_row5_col8,#T_a104c_row8_col4{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_a104c_row6_col0{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_a104c_row6_col2{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_a104c_row7_col2,#T_a104c_row8_col2{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_a104c_row8_col0{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_a104c_row8_col1{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_a104c_row8_col5{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_a104c_row8_col6{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }</style><table id="T_a104c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Engine Displacement</th>        <th class="col_heading level0 col2" >Cylinders</th>        <th class="col_heading level0 col3" >Fuel Barrels/Year</th>        <th class="col_heading level0 col4" >City MPG</th>        <th class="col_heading level0 col5" >Highway MPG</th>        <th class="col_heading level0 col6" >Combined MPG</th>        <th class="col_heading level0 col7" >CO2 Emission Grams/Mile</th>        <th class="col_heading level0 col8" >Fuel Cost/Year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a104c_level0_row0" class="row_heading level0 row0" >Year</th>
#                         <td id="T_a104c_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_a104c_row0_col1" class="data row0 col1" >0.05</td>
#                         <td id="T_a104c_row0_col2" class="data row0 col2" >0.07</td>
#                         <td id="T_a104c_row0_col3" class="data row0 col3" >-0.21</td>
#                         <td id="T_a104c_row0_col4" class="data row0 col4" >0.16</td>
#                         <td id="T_a104c_row0_col5" class="data row0 col5" >0.27</td>
#                         <td id="T_a104c_row0_col6" class="data row0 col6" >0.21</td>
#                         <td id="T_a104c_row0_col7" class="data row0 col7" >-0.22</td>
#                         <td id="T_a104c_row0_col8" class="data row0 col8" >-0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_a104c_level0_row1" class="row_heading level0 row1" >Engine Displacement</th>
#                         <td id="T_a104c_row1_col0" class="data row1 col0" >0.05</td>
#                         <td id="T_a104c_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_a104c_row1_col2" class="data row1 col2" >0.93</td>
#                         <td id="T_a104c_row1_col3" class="data row1 col3" >0.83</td>
#                         <td id="T_a104c_row1_col4" class="data row1 col4" >-0.85</td>
#                         <td id="T_a104c_row1_col5" class="data row1 col5" >-0.75</td>
#                         <td id="T_a104c_row1_col6" class="data row1 col6" >-0.82</td>
#                         <td id="T_a104c_row1_col7" class="data row1 col7" >0.83</td>
#                         <td id="T_a104c_row1_col8" class="data row1 col8" >0.79</td>
#             </tr>
#             <tr>
#                         <th id="T_a104c_level0_row2" class="row_heading level0 row2" >Cylinders</th>
#                         <td id="T_a104c_row2_col0" class="data row2 col0" >0.07</td>
#                         <td id="T_a104c_row2_col1" class="data row2 col1" >0.93</td>
#                         <td id="T_a104c_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_a104c_row2_col3" class="data row2 col3" >0.78</td>
#                         <td id="T_a104c_row2_col4" class="data row2 col4" >-0.82</td>
#                         <td id="T_a104c_row2_col5" class="data row2 col5" >-0.70</td>
#                         <td id="T_a104c_row2_col6" class="data row2 col6" >-0.78</td>
#                         <td id="T_a104c_row2_col7" class="data row

# %% [markdown]
# ### 3.2 Seaborn

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1, 1, 1)

sns.heatmap(vehicles.corr(method='spearman'), annot=True, fmt='.2f', ax=ax);

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
